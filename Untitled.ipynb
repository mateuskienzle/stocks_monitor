# %%
import pandas as pd

# %%
df_book = pd.read_csv('book_data.csv', index_col=[0])
df_book.head()
# Out:
#                   date  preco    tipo  ativo    exchange    vol  \
# 0  2021-07-23T00:00:00    123  Compra  ITUB4  BMFBOVESPA  10000
# 1  2017-02-02T00:00:00    123  Compra  MGLU3  BMFBOVESPA   7500
# 2  2022-02-02T00:00:00    123  Compra  TTEN3  BMFBOVESPA  15000
# 3  2018-02-02T00:00:00    123  Compra  VALE3  BMFBOVESPA  29000
# 4  2019-02-02T00:00:00    123  Compra  LREN3  BMFBOVESPA  50000
#
#                                          logo_url  valor_total
# 0           https://logo.clearbit.com/itau.com.br          500
# 1  https://logo.clearbit.com/magazineluiza.com.br          500
# 2     https://logo.clearbit.com/ri.3tentos.com.br          500
# 3           https://logo.clearbit.com/vale.com.br          500
# 4    https://logo.clearbit.com/lojasrenner.com.br          500

# %%
df_hist = pd.read_csv('historical_data.csv', index_col=[0])
df_hist.head()
# Out:
#               datetime            symbol     close
# 0  2002-11-29 09:00:00  BMFBOVESPA:ITUB4  0.391348
# 1  2002-12-02 09:00:00  BMFBOVESPA:ITUB4  0.402449
# 2  2002-12-03 09:00:00  BMFBOVESPA:ITUB4  0.395973
# 3  2002-12-04 09:00:00  BMFBOVESPA:ITUB4  0.395973
# 4  2002-12-05 09:00:00  BMFBOVESPA:ITUB4  0.384872

# %%
df_hist['datetime'] = pd.to_datetime(df_hist['datetime'])

# %%
df_hist = df_hist.set_index('datetime')

# %%
df_hist['date'] = df_hist.index.date

# %%
df_hist
# Out:
#                                symbol          close        date
# datetime
# 2002-11-29 09:00:00  BMFBOVESPA:ITUB4       0.391348  2002-11-29
# 2002-12-02 09:00:00  BMFBOVESPA:ITUB4       0.402449  2002-12-02
# 2002-12-03 09:00:00  BMFBOVESPA:ITUB4       0.395973  2002-12-03
# 2002-12-04 09:00:00  BMFBOVESPA:ITUB4       0.395973  2002-12-04
# 2002-12-05 09:00:00  BMFBOVESPA:ITUB4       0.384872  2002-12-05
# ...                               ...            ...         ...
# 2023-02-14 09:00:00     VANTAGE:BVSPX  105624.400000  2023-02-14
# 2023-02-15 09:00:00     VANTAGE:BVSPX  107801.570000  2023-02-15
# 2023-02-16 09:00:00     VANTAGE:BVSPX  108483.120000  2023-02-16
# 2023-02-17 09:00:00     VANTAGE:BVSPX  107192.340000  2023-02-17
# 2023-02-22 09:00:00     VANTAGE:BVSPX  105066.940000  2023-02-22
#
# [64343 rows x 3 columns]

# %%
df_hist = df_hist.groupby(['date', 'symbol'])['close'].last().to_frame().reset_index()

# %%
df_hist = df_hist.pivot(values='close', columns='symbol', index='date')

# %%
df_hist
# Out:
# symbol      BMFBOVESPA:ITUB4  BMFBOVESPA:LREN3  BMFBOVESPA:MGLU3  \
# date
# 2002-11-29          0.391348               NaN               NaN
# 2002-12-02          0.402449               NaN               NaN
# 2002-12-03          0.395973               NaN               NaN
# 2002-12-04          0.395973               NaN               NaN
# 2002-12-05          0.384872               NaN               NaN
# ...                      ...               ...               ...
# 2023-02-14         26.379999         18.719999              4.06
# 2023-02-15         26.770000         19.230000              3.89
# 2023-02-16         26.969999         19.379999              3.81
# 2023-02-17         26.879999         19.620001              3.66
# 2023-02-22         26.380000         18.690000              3.52
#
# symbol      BMFBOVESPA:TTEN3  BMFBOVESPA:VALE3  VANTAGE:BVSPX
# date
# 2002-11-29               NaN          1.381827            NaN
# 2002-12-02               NaN          1.402554            NaN
# 2002-12-03               NaN          1.409463            NaN
# 2002-12-04               NaN          1.402554            NaN
# 2002-12-05               NaN          1.423143            NaN
# ...                      ...               ...            ...
# 2023-02-14         11.964841         87.099998      105624.40
# 2023-02-15         12.750000         89.000000      107801.57
# 2023-02-16         12.770000         89.190002      108483.12
# 2023-02-17         12.620000         88.029999      107192.34
# 2023-02-22         12.660000         87.360000      105066.94
#
# [5009 rows x 6 columns]

# %%
df_cotacoes = df_hist.copy()

# %%
import numpy as np

# %%
df_cotacoes = df_cotacoes.replace({0: np.nan}).ffill().fillna(0)

# %%
df_carteira = df_hist.copy()

# %%
df_carteira.columns = [col.split(':')[-1] for col in df_carteira.columns]

# %%
df_cotacoes.columns = [col.split(':')[-1] for col in df_cotacoes.columns]

# %%
del df_carteira['BVSPX'], df_cotacoes['BVSPX']

# %%
df_book['vol'] = df_book['vol'] * df_book['tipo'].replace({'Compra': 1, 'Venda': -1})

# %%
df_book['date'] = pd.to_datetime(df_book.date)

# %%
df_book
# Out:
#         date  preco    tipo  ativo    exchange    vol  \
# 0 2021-07-23    123  Compra  ITUB4  BMFBOVESPA  10000
# 1 2017-02-02    123  Compra  MGLU3  BMFBOVESPA   7500
# 2 2022-02-02    123  Compra  TTEN3  BMFBOVESPA  15000
# 3 2018-02-02    123  Compra  VALE3  BMFBOVESPA  29000
# 4 2019-02-02    123  Compra  LREN3  BMFBOVESPA  50000
# 5 2022-07-22    123   Venda  ITUB4  BMFBOVESPA  -5000
# 6 2019-07-22    123   Venda  MGLU3  BMFBOVESPA  -2000
# 7 2020-07-22    123   Venda  LREN3  BMFBOVESPA -28000
#
#                                          logo_url  valor_total
# 0           https://logo.clearbit.com/itau.com.br          500
# 1  https://logo.clearbit.com/magazineluiza.com.br          500
# 2     https://logo.clearbit.com/ri.3tentos.com.br          500
# 3           https://logo.clearbit.com/vale.com.br          500
# 4    https://logo.clearbit.com/lojasrenner.com.br          500
# 5           https://logo.clearbit.com/itau.com.br          500
# 6  https://logo.clearbit.com/magazineluiza.com.br          500
# 7    https://logo.clearbit.com/lojasrenner.com.br          500

# %%
df_book.index = df_book['date']

# %%
df_book['date'] = df_book.index.date

# %%
df_carteira.iloc[:, :] = 0

# %%
df_carteira
# Out:
#             ITUB4  LREN3  MGLU3  TTEN3  VALE3
# date
# 2002-11-29      0      0      0      0      0
# 2002-12-02      0      0      0      0      0
# 2002-12-03      0      0      0      0      0
# 2002-12-04      0      0      0      0      0
# 2002-12-05      0      0      0      0      0
# ...           ...    ...    ...    ...    ...
# 2023-02-14      0      0      0      0      0
# 2023-02-15      0      0      0      0      0
# 2023-02-16      0      0      0      0      0
# 2023-02-17      0      0      0      0      0
# 2023-02-22      0      0      0      0      0
#
# [5009 rows x 5 columns]

# %%
for _, row in df_book.iterrows():
    df_carteira.loc[df_carteira.index >= row['date'], row['ativo']] += row['vol']

# %%
df_carteira
# Out:
#             ITUB4  LREN3  MGLU3  TTEN3  VALE3
# date
# 2002-11-29      0      0      0      0      0
# 2002-12-02      0      0      0      0      0
# 2002-12-03      0      0      0      0      0
# 2002-12-04      0      0      0      0      0
# 2002-12-05      0      0      0      0      0
# ...           ...    ...    ...    ...    ...
# 2023-02-14   5000  22000   5500  15000  29000
# 2023-02-15   5000  22000   5500  15000  29000
# 2023-02-16   5000  22000   5500  15000  29000
# 2023-02-17   5000  22000   5500  15000  29000
# 2023-02-22   5000  22000   5500  15000  29000
#
# [5009 rows x 5 columns]

# %%
df_patrimonio = df_cotacoes * df_carteira

# %%
df_patrimonio
# Out:
#                  ITUB4       LREN3    MGLU3       TTEN3        VALE3
# date
# 2002-11-29       0.000       0.000      0.0       0.000        0.000
# 2002-12-02       0.000       0.000      0.0       0.000        0.000
# 2002-12-03       0.000       0.000      0.0       0.000        0.000
# 2002-12-04       0.000       0.000      0.0       0.000        0.000
# 2002-12-05       0.000       0.000      0.0       0.000        0.000
# ...                ...         ...      ...         ...          ...
# 2023-02-14  131899.995  411839.978  22330.0  179472.615  2525899.942
# 2023-02-15  133850.000  423060.000  21395.0  191250.000  2581000.000
# 2023-02-16  134849.995  426359.978  20955.0  191550.000  2586510.058
# 2023-02-17  134399.995  431640.022  20130.0  189300.000  2552869.971
# 2023-02-22  131900.000  411180.000  19360.0  189900.000  2533440.000
#
# [5009 rows x 5 columns]

# %%
df_patrimonio = df_patrimonio.fillna(0)

# %%
df_patrimonio['soma'] = df_patrimonio.sum(axis=1)

# %%
df_patrimonio
# Out:
#                  ITUB4       LREN3    MGLU3       TTEN3        VALE3  \
# date
# 2002-11-29       0.000       0.000      0.0       0.000        0.000
# 2002-12-02       0.000       0.000      0.0       0.000        0.000
# 2002-12-03       0.000       0.000      0.0       0.000        0.000
# 2002-12-04       0.000       0.000      0.0       0.000        0.000
# 2002-12-05       0.000       0.000      0.0       0.000        0.000
# ...                ...         ...      ...         ...          ...
# 2023-02-14  131899.995  411839.978  22330.0  179472.615  2525899.942
# 2023-02-15  133850.000  423060.000  21395.0  191250.000  2581000.000
# 2023-02-16  134849.995  426359.978  20955.0  191550.000  2586510.058
# 2023-02-17  134399.995  431640.022  20130.0  189300.000  2552869.971
# 2023-02-22  131900.000  411180.000  19360.0  189900.000  2533440.000
#
#                    soma
# date
# 2002-11-29        0.000
# 2002-12-02        0.000
# 2002-12-03        0.000
# 2002-12-04        0.000
# 2002-12-05        0.000
# ...                 ...
# 2023-02-14  3271442.530
# 2023-02-15  3350555.000
# 2023-02-16  3360225.031
# 2023-02-17  3328339.988
# 2023-02-22  3285780.000
#
# [5009 rows x 6 columns]

# %%
df_ops = df_carteira - df_carteira.shift(1)

# %%
df_ops.loc[df_ops['ITUB4'] != 0, 'ITUB4']
# Out:
# date
# 2002-11-29        NaN
# 2021-07-23    10000.0
# 2022-07-22    -5000.0
# Name: ITUB4, dtype: float64

# %%
df_ops = df_ops * df_cotacoes

# %%
df_patrimonio['evolucao_patrimonial'] = df_patrimonio['soma'].diff() - df_ops.sum(axis=1)

# %%
df_patrimonio['evolucao_patrimonial'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_patrimonio['evolucao_patrimonial'].max()
# Out:
# 343818.53069499973

# %%
df_patrimonio[df_patrimonio['evolucao_patrimonial'] == df_patrimonio['evolucao_patrimonial'].min()]
# Out:
#             ITUB4         LREN3         MGLU3  TTEN3         VALE3  \
# date
# 2020-03-16    0.0  1.595940e+06  46710.713115    0.0  844082.90967
#
#                     soma  evolucao_patrimonial
# date
# 2020-03-16  2.486734e+06        -521643.166575

# %%
(df_patrimonio['evolucao_patrimonial'] / df_patrimonio['soma'] * 100).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_patrimonio['evolucao_percentual'] = (df_patrimonio['evolucao_patrimonial'] / df_patrimonio['soma'])

# %%
ev_total_list = [1]*len(df_patrimonio)

# %%
df_patrimonio['evolucao_percentual'] = df_patrimonio['evolucao_percentual'].fillna(0)

# %%
for i, x in enumerate(df_patrimonio['evolucao_percentual'].to_list()[1:]):
    ev_total_list[i+1] = ev_total_list[i] * (1 + x)

# %%
df_patrimonio['evolucao_cum'] = ev_total_list

# %%
((df_patrimonio['evolucao_cum'] - 1) * 100).plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_patrimonio
# Out:
#                  ITUB4       LREN3    MGLU3       TTEN3        VALE3  \
# date
# 2002-11-29       0.000       0.000      0.0       0.000        0.000
# 2002-12-02       0.000       0.000      0.0       0.000        0.000
# 2002-12-03       0.000       0.000      0.0       0.000        0.000
# 2002-12-04       0.000       0.000      0.0       0.000        0.000
# 2002-12-05       0.000       0.000      0.0       0.000        0.000
# ...                ...         ...      ...         ...          ...
# 2023-02-14  131899.995  411839.978  22330.0  179472.615  2525899.942
# 2023-02-15  133850.000  423060.000  21395.0  191250.000  2581000.000
# 2023-02-16  134849.995  426359.978  20955.0  191550.000  2586510.058
# 2023-02-17  134399.995  431640.022  20130.0  189300.000  2552869.971
# 2023-02-22  131900.000  411180.000  19360.0  189900.000  2533440.000
#
#                    soma  evolucao_patrimonial  evolucao_percentual  \
# date
# 2002-11-29        0.000                   NaN             0.000000
# 2002-12-02        0.000                 0.000             0.000000
# 2002-12-03        0.000                 0.000             0.000000
# 2002-12-04        0.000                 0.000             0.000000
# 2002-12-05        0.000                 0.000             0.000000
# ...                 ...                   ...                  ...
# 2023-02-14  3271442.530             -6890.751            -0.002106
# 2023-02-15  3350555.000             79112.470             0.023612
# 2023-02-16  3360225.031              9670.031             0.002878
# 2023-02-17  3328339.988            -31885.043            -0.009580
# 2023-02-22  3285780.000            -42559.988            -0.012953
#
#             evolucao_cum
# date
# 2002-11-29      1.000000
# 2002-12-02      1.000000
# 2002-12-03      1.000000
# 2002-12-04      1.000000
# 2002-12-05      1.000000
# ...                  ...
# 2023-02-14      3.329565
# 2023-02-15      3.408182
# 2023-02-16      3.417990
# 2023-02-17      3.385246
# 2023-02-22      3.341398
#
# [5009 rows x 9 columns]
